# %%
from pyleri import Grammar, Keyword, Sequence, Choice, Token
import csv

# %%
names: list[str] = list()
verbs: dict[str, str] = dict()
with open("verbs.csv", "r", encoding='utf-8') as f:
    r = csv.reader(f, delimiter=',')
    names.extend(next(r))
    for row in r:
        base: str = ""
        for i, (name, verb) in enumerate(zip(names, row)):
            if i % 32 == 0:
                base = verb.replace(" ", "_")
            grammar_name = base + "_" + name.replace("-", "Q")
            verbs[grammar_name.upper()] = verb

print(verbs)

"""
verb_(SG, PL)_(NOM, GEN, DAT, AC, INS, LOC, VOC)_(M,F,N,-)_(1,2,3)_(PRES,PAST,-)_(IND,PRE)
SG_GEN_-_1_PRES_IND,słucham
SG_GEN_-_2_PRES_IND,słuchasz
SG_GEN_-_3_PRES_IND,słucha
PL_GEN_-_1_PRES_IND,słuchamy
PL_GEN_-_2_PRES_IND,słuchacie
PL_GEN_-_3_PRES_IND,słuchają
SG_GEN_M_1_PAST_IND,słuchałem
SG_GEN_F_1_PAST_IND,słuchałam
SG_GEN_M_2_PAST_IND,słuchałeś
SG_GEN_F_2_PAST_IND,słuchałaś
SG_GEN_M_3_PAST_IND,słuchał
SG_GEN_F_3_PAST_IND,słuchała
SG_GEN_N_3_PAST_IND,słuchało
PL_GEN_M_1_PAST_IND,słuchaliśmy
PL_GEN_F_1_PAST_IND,słuchałyśmy
PL_GEN_M_2_PAST_IND,słuchaliście
PL_GEN_F_2_PAST_IND,słuchałyście
PL_GEN_M_3_PAST_IND,słuchali
PL_GEN_F_3_PAST_IND,słuchały
SG_GEN_M_1_-_PRE,słuchałbym
SG_GEN_F_1_-_PRE,słuchałabym
SG_GEN_M_2_-_PRE,słuchałbyś
SG_GEN_F_2_-_PRE,słuchałabyś
SG_GEN_M_3_-_PRE,słuchałby
SG_GEN_F_3_-_PRE,słuchałaby
SG_GEN_N_3_-_PRE,słuchałoby
PL_GEN_M_1_-_PRE,słuchalibyśmy
PL_GEN_F_1_-_PRE,słuchałybyście
PL_GEN_M_2_-_PRE,słuchalibyście
PL_GEN_F_2_-_PRE,słuchałybyście
PL_GEN_M_3_-_PRE,słuchaliby
PL_GEN_F_3_-_PRE,słuchałyby
"""
# Out:
# {'SŁUCHAĆ_VERB': 'słuchać', 'SŁUCHAĆ_SG_GEN_Q_1_PRES_IND': 'słucham', 'SŁUCHAĆ_SG_GEN_Q_2_PRES_IND': 'słuchasz', 'SŁUCHAĆ_SG_GEN_Q_3_PRES_IND': 'słucha', 'SŁUCHAĆ_PL_GEN_Q_1_PRES_IND': 'słuchamy', 'SŁUCHAĆ_PL_GEN_Q_2_PRES_IND': 'słuchacie', 'SŁUCHAĆ_PL_GEN_Q_3_PRES_IND': 'słuchają', 'SŁUCHAĆ_SG_GEN_M_1_PAST_IND': 'słuchałem', 'SŁUCHAĆ_SG_GEN_F_1_PAST_IND': 'słuchałam', 'SŁUCHAĆ_SG_GEN_M_2_PAST_IND': 'słuchałeś', 'SŁUCHAĆ_SG_GEN_F_2_PAST_IND': 'słuchałaś', 'SŁUCHAĆ_SG_GEN_M_3_PAST_IND': 'słuchał', 'SŁUCHAĆ_SG_GEN_F_3_PAST_IND': 'słuchała', 'SŁUCHAĆ_SG_GEN_N_3_PAST_IND': 'słuchało', 'SŁUCHAĆ_PL_GEN_M_1_PAST_IND': 'słuchaliśmy', 'SŁUCHAĆ_PL_GEN_F_1_PAST_IND': 'słuchałyśmy', 'SŁUCHAĆ_PL_GEN_M_2_PAST_IND': 'słuchaliście', 'SŁUCHAĆ_PL_GEN_F_2_PAST_IND': 'słuchałyście', 'SŁUCHAĆ_PL_GEN_M_3_PAST_IND': 'słuchali', 'SŁUCHAĆ_PL_GEN_F_3_PAST_IND': 'słuchały', 'SŁUCHAĆ_SG_GEN_M_1_Q_PRE': 'słuchałbym', 'SŁUCHAĆ_SG_GEN_F_1_Q_PRE': 'słuchałabym', 'SŁUCHAĆ_SG_GEN_M_2_Q_PRE': 'słuchałbyś', 'SŁUCHAĆ_SG
# ...

# %%
names: list[str] = list()
nouns: dict[str, str] = dict()
with open("nouns.csv", "r", encoding='utf-8') as f:
    r = csv.reader(f, delimiter=',')
    names.extend(next(r))
    for row in r:
        base: str = ""
        for i, (name, noun) in enumerate(zip(names, row)):
            if i % 14 == 0:
                base = noun
            grammar_name = base + "_" + name
            nouns[grammar_name.upper()] = noun

print(nouns)
# Out:
# {'ZAMEK_SG_NOM_M': 'zamek', 'ZAMEK_SG_GEN_M': 'zamku', 'ZAMEK_SG_DAT_M': 'zamkowi', 'ZAMEK_SG_ACC_M': 'zamek', 'ZAMEK_SG_INS_M': 'zamkiem', 'ZAMEK_SG_LOC_M': 'zamku', 'ZAMEK_SG_VOC_M': 'zamku', 'ZAMEK_PL_NOM_M': 'zamki', 'ZAMEK_PL_GEN_M': 'zamków', 'ZAMEK_PL_DAT_M': 'zamkom', 'ZAMEK_PL_ACC_M': 'zamki', 'ZAMEK_PL_INS_M': 'zamkami', 'ZAMEK_PL_LOC_M': 'zamkach', 'ZAMEK_PL_VOC_M': 'zamki', 'KOBIETA_SG_NOM_F': 'kobieta', 'KOBIETA_SG_GEN_F': 'kobiety', 'KOBIETA_SG_DAT_F': 'kobiecie', 'KOBIETA_SG_ACC_F': 'kobietę', 'KOBIETA_SG_INS_F': 'kobietą', 'KOBIETA_SG_LOC_F': 'kobiecie', 'KOBIETA_SG_VOC_F': 'kobieto', 'KOBIETA_PL_NOM_F': 'kobiety', 'KOBIETA_PL_GEN_F': 'kobiet', 'KOBIETA_PL_DAT_F': 'kobietom', 'KOBIETA_PL_ACC_F': 'kobiety', 'KOBIETA_PL_INS_F': 'kobietami', 'KOBIETA_PL_LOC_F': 'kobietach', 'KOBIETA_PL_VOC_F': 'kobiety', 'OKNO_SG_NOM_N': 'okno', 'OKNO_SG_GEN_N': 'okna', 'OKNO_SG_DAT_N': 'oknu', 'OKNO_SG_ACC_N': 'okno', 'OKNO_SG_INS_N': 'oknem', 'OKNO_SG_LOC_N': 'oknie', 'OKNO_SG_VOC_N': 
# ...

# %%
keywords = ""
for k, v in nouns.items():
    keywords += f"\t{k} = Keyword('{v}')\n"
# for k, v in verbs.items():
#     keywords += f"\t{k} = Keyword('{v}')\n"
print(keywords)
# Out:
# 	ZAMEK_SG_NOM_M = Keyword('zamek')
# 	ZAMEK_SG_GEN_M = Keyword('zamku')
# 	ZAMEK_SG_DAT_M = Keyword('zamkowi')
# 	ZAMEK_SG_ACC_M = Keyword('zamek')
# 	ZAMEK_SG_INS_M = Keyword('zamkiem')
# 	ZAMEK_SG_LOC_M = Keyword('zamku')
# 	ZAMEK_SG_VOC_M = Keyword('zamku')
# 	ZAMEK_PL_NOM_M = Keyword('zamki')
# 	ZAMEK_PL_GEN_M = Keyword('zamków')
# 	ZAMEK_PL_DAT_M = Keyword('zamkom')
# 	ZAMEK_PL_ACC_M = Keyword('zamki')
# 	ZAMEK_PL_INS_M = Keyword('zamkami')
# 	ZAMEK_PL_LOC_M = Keyword('zamkach')
# 	ZAMEK_PL_VOC_M = Keyword('zamki')
# 	KOBIETA_SG_NOM_F = Keyword('kobieta')
# 	KOBIETA_SG_GEN_F = Keyword('kobiety')
# 	KOBIETA_SG_DAT_F = Keyword('kobiecie')
# 	KOBIETA_SG_ACC_F = Keyword('kobietę')
# 	KOBIETA_SG_INS_F = Keyword('kobietą')
# 	KOBIETA_SG_LOC_F = Keyword('kobiecie')
# 	KOBIETA_SG_VOC_F = Keyword('kobieto')
# 	KOBIETA_PL_NOM_F = Keyword('kobiety')
# 	KOBIETA_PL_GEN_F = Keyword('kobiet')
# 	KOBIETA_PL_DAT_F = Keyword('kobietom')
# 	KOBIETA_PL_ACC_F = Keyword('kobiety')
# ...

# %%
categorized_verbs: dict[str, str] = dict()
for key in verbs:
    data = key.split('_')
    if len(data) <= 3:
        continue
    while data[1] not in ["PL", "SG"]:
        data.pop(0)
    name = "VERB_" + "_".join(data[1:])
    if name in categorized_verbs:
        categorized_verbs[name] += f", {key}"
    else:
        categorized_verbs[name] = f"{name} = Choice({key}"
        
categorized_verbs_str: str = ""
for v in categorized_verbs.values():
    categorized_verbs_str += f"\t{v})\n"
print(categorized_verbs_str)
# Out:
# 	VERB_SG_GEN_Q_1_PRES_IND = Choice(SŁUCHAĆ_SG_GEN_Q_1_PRES_IND, CZYTAĆ_SG_GEN_Q_1_PRES_IND, PISAĆ_SG_GEN_Q_1_PRES_IND, ROBIĆ_SG_GEN_Q_1_PRES_IND, JEŚĆ_SG_GEN_Q_1_PRES_IND, MIEĆ_SG_GEN_Q_1_PRES_IND, IŚĆ_SG_GEN_Q_1_PRES_IND, PIĆ_SG_GEN_Q_1_PRES_IND, BRAĆ_SG_GEN_Q_1_PRES_IND, DAĆ_SG_GEN_Q_1_PRES_IND, ZNAĆ_SG_GEN_Q_1_PRES_IND, SPAĆ_SG_GEN_Q_1_PRES_IND, WIDZIEĆ_SG_GEN_Q_1_PRES_IND, CHCIEĆ_SG_GEN_Q_1_PRES_IND, MÓWIĆ_SG_GEN_Q_1_PRES_IND, KOCHAĆ_SG_GEN_Q_1_PRES_IND, PRACOWAĆ_SG_GEN_Q_1_PRES_IND, ŻYĆ_SG_GEN_Q_1_PRES_IND, NAPISAĆ_SG_GEN_Q_1_PRES_IND, ZJEŚĆ_SG_GEN_Q_1_PRES_IND, OBEJRZEĆ_SG_GEN_Q_1_PRES_IND, KUPIĆ_SG_GEN_Q_1_PRES_IND, POJECHAĆ_SG_GEN_Q_1_PRES_IND, POWIEDZIEĆ_SG_GEN_Q_1_PRES_IND, CZYŚCIĆ_SG_GEN_Q_1_PRES_IND, BIEGAĆ_SG_GEN_Q_1_PRES_IND, UGOTOWAĆ_SG_GEN_Q_1_PRES_IND, POMAGAĆ_SG_GEN_Q_1_PRES_IND, MALOWAĆ_SG_GEN_Q_1_PRES_IND, GOTOWAĆ_SG_GEN_Q_1_PRES_IND, ZROZUMIEĆ_SG_GEN_Q_1_PRES_IND, PŁAKAĆ_SG_GEN_Q_1_PRES_IND, ŚMIAĆ_SIĘ_SG_GEN_Q_1_PRES_IND, TAŃCZYĆ_SG_GEN_Q_1_PRES_IND, ZAMYŚLIĆ_SIĘ
# ...

# %%
categorized_nouns: dict[str, str] = dict()
for key in nouns:
    data = key.split('_')
    name = "NOUN_" + "_".join(data[1:])
    if name in categorized_nouns:
        categorized_nouns[name] += f", {key}"
    else:
        categorized_nouns[name] = f"{name} = Choice({key}"

categorized_nouns_str: str = ""
for v in categorized_nouns.values():
    categorized_nouns_str += f"\t{v})\n"
print(categorized_nouns_str)
# Out:
# 	NOUN_SG_NOM_M = Choice(ZAMEK_SG_NOM_M, PIES_SG_NOM_M, DOM_SG_NOM_M, STÓŁ_SG_NOM_M, STUDENT_SG_NOM_M, KOT_SG_NOM_M, KRÓL_SG_NOM_M, CZŁOWIEK_SG_NOM_M, PAN_SG_NOM_M, NAUCZYCIEL_SG_NOM_M, CHŁOPIEC_SG_NOM_M, RYCERZ_SG_NOM_M, STRAŻAK_SG_NOM_M, LEKARZ_SG_NOM_M, PILOT_SG_NOM_M, WOJOWNIK_SG_NOM_M, ŻOŁNIERZ_SG_NOM_M, UCZEŃ_SG_NOM_M, ARTYSTA_SG_NOM_M, MALARZ_SG_NOM_M, PTAK_SG_NOM_M, ŻEGLARZ_SG_NOM_M, SPORTOWIEC_SG_NOM_M, KOWAL_SG_NOM_M, AKTOR_SG_NOM_M, INŻYNIER_SG_NOM_M, POLICJANT_SG_NOM_M, MECHANIK_SG_NOM_M, MUZYK_SG_NOM_M, NAUKOWIEC_SG_NOM_M, PISARZ_SG_NOM_M, KUCHARZ_SG_NOM_M, GÓRNIK_SG_NOM_M)
# ...

# %%
everything = ""
for key in categorized_nouns:
    everything += key + ", "

print(everything)
# Out:
# NOUN_SG_NOM_M, NOUN_SG_GEN_M, NOUN_SG_DAT_M, NOUN_SG_ACC_M, NOUN_SG_INS_M, NOUN_SG_LOC_M, NOUN_SG_VOC_M, NOUN_PL_NOM_M, NOUN_PL_GEN_M, NOUN_PL_DAT_M, NOUN_PL_ACC_M, NOUN_PL_INS_M, NOUN_PL_LOC_M, NOUN_PL_VOC_M, NOUN_SG_NOM_F, NOUN_SG_GEN_F, NOUN_SG_DAT_F, NOUN_SG_ACC_F, NOUN_SG_INS_F, NOUN_SG_LOC_F, NOUN_SG_VOC_F, NOUN_PL_NOM_F, NOUN_PL_GEN_F, NOUN_PL_DAT_F, NOUN_PL_ACC_F, NOUN_PL_INS_F, NOUN_PL_LOC_F, NOUN_PL_VOC_F, NOUN_SG_NOM_N, NOUN_SG_GEN_N, NOUN_SG_DAT_N, NOUN_SG_ACC_N, NOUN_SG_INS_N, NOUN_SG_LOC_N, NOUN_SG_VOC_N, NOUN_PL_NOM_N, NOUN_PL_GEN_N, NOUN_PL_DAT_N, NOUN_PL_ACC_N, NOUN_PL_INS_N, NOUN_PL_LOC_N, NOUN_PL_VOC_N,

# %%
my_grammar: Grammar
exec(
f"class MyGrammar(Grammar):\n"
f"{keywords}"
f"{categorized_nouns_str}"
# f"{categorized_verbs_str}"
f"\tUNUSED = Keyword('kurwa')\n"
f"\tMIEC_PRES_3SG = Keyword('ma')\n"
f"\tverb_sg_acc = Choice(MIEC_PRES_3SG)\n"
f"\tSTART = Choice("
f"Sequence("
f"Choice(NOUN_SG_NOM_N, NOUN_SG_NOM_F, NOUN_SG_NOM_M),"
f"verb_sg_acc,"
f"Choice(NOUN_SG_ACC_N, NOUN_SG_ACC_F, NOUN_SG_ACC_M, NOUN_PL_ACC_N, NOUN_PL_ACC_F, NOUN_PL_ACC_M)"
f")"
f", Sequence("
f"UNUSED,"
f"Choice(NOUN_SG_NOM_M, NOUN_SG_GEN_M, NOUN_SG_DAT_M, NOUN_SG_ACC_M, NOUN_SG_INS_M, NOUN_SG_LOC_M, NOUN_SG_VOC_M, NOUN_PL_NOM_M, NOUN_PL_GEN_M, NOUN_PL_DAT_M, NOUN_PL_ACC_M, NOUN_PL_INS_M, NOUN_PL_LOC_M, NOUN_PL_VOC_M, NOUN_SG_NOM_F, NOUN_SG_GEN_F, NOUN_SG_DAT_F, NOUN_SG_ACC_F, NOUN_SG_INS_F, NOUN_SG_LOC_F, NOUN_SG_VOC_F, NOUN_PL_NOM_F, NOUN_PL_GEN_F, NOUN_PL_DAT_F, NOUN_PL_ACC_F, NOUN_PL_INS_F, NOUN_PL_LOC_F, NOUN_PL_VOC_F, NOUN_SG_NOM_N, NOUN_SG_GEN_N, NOUN_SG_DAT_N, NOUN_SG_ACC_N, NOUN_SG_INS_N, NOUN_SG_LOC_N, NOUN_SG_VOC_N, NOUN_PL_NOM_N, NOUN_PL_GEN_N, NOUN_PL_DAT_N, NOUN_PL_ACC_N, NOUN_PL_INS_N, NOUN_PL_LOC_N, NOUN_PL_VOC_N)"
f")"
f")")

# %%
# class MyGrammar(Grammar):
#     """
#     base noun, number (pl, sg), conjugate (nom, gen, dat, acc, ins, loc, voc), gender (m, f, n)
#     base adjective, number (pl, sg), conjugate (nom, gen, dat, acc, ins, loc, voc), gender (m, f, n)
#     base verb, number (pl, sg), conjugate (nom, gen, dat, acc, ins, loc, voc), gender (m, f, n), person (1,2,3), time (past, pres, futu), mode (ind, pre, imp)
#     """
#     ZAMEK_SG_NOM = Keyword('zamek')
#     ZAMEK_SG_ACC = Keyword('zamek')
#     ZAMEK_PL_ACC = Keyword('zamki')
#     ALA_SG_ACC = Keyword('Alę')
#     MIEC_PRES_3SG = Keyword('ma')
#     object_sg_nom = Choice(ZAMEK_SG_NOM)
#     object_sg_acc = Choice(ZAMEK_SG_ACC, ALA_SG_ACC)
#     object_pl_acc = Choice(ZAMEK_PL_ACC)
#     subject_sg = Choice(object_sg_nom)
#     object_acc = Choice(object_sg_acc, object_pl_acc)
#     verb_sg_acc = Choice(MIEC_PRES_3SG)
#     START = Sequence(subject_sg, verb_sg_acc, object_acc)
# 
# # Compile your grammar by creating an instance of the Grammar Class.
# my_grammar = MyGrammar()
# 
# print(my_grammar.parse('zamek ma Alęęę').as_str()) # => error at position 0, expecting: hi

# %%
my_grammar = MyGrammar()

# %%
import tkinter as tk
from tkinter import font

# INTERESTING return type("Result", (), {"pos": None, "expecting": {"I", "like", "apples", "and", "bananas"}})()


class GrammarEditor:
    def __init__(self, root):
        self.root = root
        self.root.title("Grammar Learning Editor")
        self.text = tk.Text(root, wrap="word", undo=True)
        self.text.pack(fill="both", expand=True)
        self.text.focus_set()

        self.text.bind("<KeyRelease>", self.on_text_change)
        self.text.bind("<Tab>", self.on_tab)
        self.root.bind_all("<Up>", self.on_up, add="+")
        self.root.bind_all("<Down>", self.on_down, add="+")
        self.text.tag_configure("error", underline=True, foreground="red")

        # Popup for suggestions with scrollbar
        popup_frame = tk.Frame(root)
        
        self.popup_scrollbar = tk.Scrollbar(popup_frame, orient="vertical")
        self.popup = tk.Listbox(popup_frame, height=10, yscrollcommand=self.popup_scrollbar.set)
        self.popup_scrollbar.config(command=self.popup.yview)
        
        # Pack inside the frame (Listbox on left, scrollbar on right)
        self.popup.pack(side="left", fill="both", expand=True)
        self.popup_scrollbar.pack(side="right", fill="y")
        
        # Store frame instead of Listbox directly for placement
        self.popup_frame = popup_frame
        
        self.popup.bind("<Double-Button-1>", self.apply_suggestion)
        self.popup.bind("<Return>", self.apply_suggestion)
        self.popup_is_visible = False

        self.selected: int = 0
        self.suggestions = []
        self.error_pos = None

    def on_text_change(self, event=None):
        text = self.text.get("1.0", "end-1c")
        
        current_word = "" if text == "" or text.endswith(" ") else text.split()[-1]
        result = my_grammar.parse(text)

        # Clear error tag
        self.text.tag_remove("error", "1.0", "end")

        # Hide popup if not needed
        self.suggestions = [str(elem) for elem in result.expecting if str(elem).startswith(current_word)]
        if len(self.suggestions) == 0:
            self.hide_popup()
            return
        
        self.error_pos = result.pos

        # Get text index for red underline
        index = self.text.index(f"1.0+{result.pos}c")
        next_space = self.text.search(r"\s", index, regexp=True)
        if not next_space:
            next_space = "end"

        self.text.tag_add("error", index, next_space)
        self.show_popup(index, self.suggestions)

    def show_popup(self, index, suggestions):
        bbox = self.text.bbox(index)
        if not bbox:
            self.hide_popup()
            return
    
        x, y, width, height = bbox
        self.popup_frame.place(x=x, y=y + height)
        self.popup.delete(0, tk.END)
        for s in suggestions:
            self.popup.insert(tk.END, s)
        self.popup_is_visible = True
        self.popup.selection_clear(0, tk.END)
        self.popup.selection_set(self.selected)
        self.popup.see(self.popup.curselection())
    
    def hide_popup(self):
        self.popup_frame.place_forget()
        self.popup_is_visible = False


    def on_tab(self, event):
        if self.popup_is_visible and self.suggestions:
            suggestion = self.suggestions[self.popup.curselection()[0]]
            self.insert_suggestion(suggestion)
            return "break"  # Prevent default tab
        return None
    
    def on_up(self, event):
        """Navigate popup list upward."""
        if not self.popup_is_visible:
            return None
        cur = self.popup.curselection()
        if not cur:
            new = 0
        else:
            new = (cur[0] - 1) % self.popup.size()
        self.selected = new
        self.popup.selection_clear(0, tk.END)
        self.popup.selection_set(new)
        self.popup.activate(new)
        self.popup.see(new)  # 👈 ensure visible in scroll region
        return "break"
    
    def on_down(self, event):
        """Navigate popup list downward."""
        if not self.popup_is_visible:
            return None
        cur = self.popup.curselection()
        if not cur:
            new = 0
        else:
            new = (cur[0] + 1) % self.popup.size()
        self.selected = new
        self.popup.selection_clear(0, tk.END)
        self.popup.selection_set(new)
        self.popup.activate(new)
        self.popup.see(new)  # 👈 ensure visible in scroll region
        return "break"


    def apply_suggestion(self, event):
        if self.popup_is_visible:
            suggestion = self.suggestions[self.popup.curselection()[0]]
            self.insert_suggestion(suggestion)

    def insert_suggestion(self, suggestion):
        if self.error_pos is not None:
            start = self.text.index(f"1.0+{self.error_pos}c")
            next_space = self.text.search(r"\s", start, regexp=True)
            if not next_space:
                next_space = "end"
            print(start)
            self.text.delete(start, next_space)
            self.text.insert(start, suggestion + " ")
            self.hide_popup()
            self.on_text_change()


if __name__ == "__main__":
    root = tk.Tk()
    app = GrammarEditor(root)
    root.mainloop()
# Out:
# 1.0
# 1.6
# 1.9

# %%
def on_text_change(self, event=None):
    text = self.text.get("1.0", "end-1c")

    current_word = "" if text == "" or text.endswith(" ") else text.split()[-1]
    result = my_grammar.parse(text)

    # Clear error tag
    self.text.tag_remove("error", "1.0", "end")

    # Build suggestions filtered by current_word
    self.suggestions = [str(elem) for elem in result.expecting if str(elem).startswith(current_word)]
    if len(self.suggestions) == 0:
        self.hide_popup()
        return

    # Keep selected index within bounds (so selection doesn't drift off after repopulate)
    if self.selected >= len(self.suggestions):
        self.selected = 0

    self.error_pos = result.pos

    # Get text index for red underline
    index = self.text.index(f"1.0+{result.pos}c")
    next_space = self.text.search(r"\s", index, regexp=True)
    if not next_space:
        next_space = "end"

    self.text.tag_add("error", index, next_space)
    self.show_popup(index, self.suggestions)


def show_popup(self, index, suggestions):
    bbox = self.text.bbox(index)
    if not bbox:
        self.hide_popup()
        return

    x, y, width, height = bbox

    # Convert text widget-local coords (bbox) to root-window coords for place()
    widget_root_x = self.text.winfo_rootx() - self.root.winfo_rootx()
    widget_root_y = self.text.winfo_rooty() - self.root.winfo_rooty()
    place_x = widget_root_x + x
    place_y = widget_root_y + y + height

    # place the frame that contains the listbox+scrollbar
    self.popup_frame.place(x=place_x, y=place_y)

    # Repopulate listbox
    self.popup.delete(0, tk.END)
    for s in suggestions:
        self.popup.insert(tk.END, s)

    # ensure selected index is valid
    if self.selected >= self.popup.size():
        self.selected = 0

    self.popup.selection_clear(0, tk.END)
    self.popup.selection_set(self.selected)
    self.popup.activate(self.selected)
    # Make sure the selection is visible
    self.popup.see(self.selected)

    self.popup_is_visible = True
    self.popup.lift()


def on_up(self, event):
    """Navigate popup list upward."""
    if not self.popup_is_visible:
        return None
    cur = self.popup.curselection()
    if not cur:
        new = 0
    else:
        new = (cur[0] - 1) % self.popup.size()
    self.selected = new
    self.popup.selection_clear(0, tk.END)
    self.popup.selection_set(new)
    self.popup.activate(new)
    self.popup.see(new)  # ensure visible
    return "break"


def on_down(self, event):
    """Navigate popup list downward."""
    if not self.popup_is_visible:
        return None
    cur = self.popup.curselection()
    if not cur:
        new = 0
    else:
        new = (cur[0] + 1) % self.popup.size()
    self.selected = new
    self.popup.selection_clear(0, tk.END)
    self.popup.selection_set(new)
    self.popup.activate(new)
    self.popup.see(new)  # ensure visible
    return "break"
